# %%
#Variables:
#rule 1: No namespaces for declaring the variables
#rule 2: A variable name should not start with a number
#rule 3: A varibale name should not contain any special characters

# %%
first name= 'Afroz'
print(first name)
# Out:
#   Cell In[9], line 1
#     first name= 'Afroz'
#           ^
# SyntaxError: invalid syntax

# %%
firstname= 'Afroz'
print(firstname)
# Out:
# Afroz

# %%
1name = 'Afroz'
print(1name)
# Out:
#   Cell In[12], line 1
#     1name = 'Afroz'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'Afroz'
print(name1)
# Out:
# Afroz

# %%
test@ = 'Afroz'
print(test@)
# Out:
#   Cell In[14], line 1
#     test@ = 'Afroz'
#           ^
# SyntaxError: invalid syntax

# %%
#Datatypes in python :
#1. string       ---> str
#2. numbers      ---> integers (init) and (float)
#3. list         ---> list
#4. tuples       ---> tuple
#5. dictionaries ---> dict

#Classification of datatypes:
#1- mutable datatypes   ---> flexible
#2- immutable datatypes ---> fixed

#String datatype - immutable
#1- single quotes
#2- double quotes

# %%
fname = 'Afroz'   #single quote
lname = "Shaikh"  #double quote
print(fname)
print(lname)
# Out:
# Afroz
# Shaikh

# %%
fullname = 'Afroz shaikh'
print(fullname.title()) 
print(fullname.upper()) #capital letters
print(fullname.lower()) #small letters
# Out:
# Afroz Shaikh
# AFROZ SHAIKH
# afroz shaikh
